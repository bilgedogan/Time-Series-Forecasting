# %% [markdown]
# https://www.bgc-jena.mpg.de/wetter/
#
# https://www.machinelearningplus.com/time-series/arima-model-time-series-forecasting-python/

# %%
# import required libraries

# data preprocessing
import pandas as pd
import numpy as np
from datetime import datetime

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import IsolationForest

# visualization
from matplotlib import pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (15.0, 6.0)


# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Preprocessing

# %%
data = pd.read_csv("mpi_roof\mpi_roof.csv",encoding= 'unicode_escape')
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31931 entries, 0 to 31930
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date Time             31931 non-null  object
#  1   p (mbar)              31931 non-null  float64
#  2   T (degC)              31931 non-null  float64
#  3   Tpot (K)              31931 non-null  float64
#  4   Tdew (degC)           31931 non-null  float64
#  5   rh (%)                31931 non-null  float64
#  6   VPmax (mbar)          31931 non-null  float64
#  7   VPact (mbar)          31931 non-null  float64
#  8   VPdef (mbar)          31931 non-null  float64
#  9   sh (g/kg)             31931 non-null  float64
#  10  H2OC (mmol/mol)       31931 non-null  float64
#  11  rho (g/m**3)          31931 non-null  float64
#  12  wv (m/s)              31931 non-null  float64
#  13  max. wv (m/s)         31931 non-null  float64
#  14  wd (deg)              31931 non-null  float64
#  15  rain (mm)             31931 non-null  float64
#  16  raining (s)           31931 non-null  int64
#  17  SWDR (W/m²)           31931 non-null  float64
#  18  PAR (µmol/m²/s)       31931 non-null  float64
#  19  max. PAR (µmol/m²/s)  31931 non-null  float64
#  20  Tlog (degC)           31931 non-null  float64
#  21  CO2 (ppm)             31931 non-null  float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 5.4+ MB
#            p (mbar)      T (degC)      Tpot (K)   Tdew (degC)        rh (%)  \
# count  31931.000000  31931.000000  31931.000000  31931.000000  31931.000000
# mean     990.646484     10.966426    284.885015      6.840672     79.511083
# std        8.268963      8.751587      8.807894      6.027105     19.419032
# min      955.430000    -13.390000    259.340000    -14.190000     14.230000
# 25%      985.930000      4.610000    278.640000      2.890000     68.700000
# 50%      991.160000     11.070000    285.160000      7.330000     84.200000
# 75%      995.540000     17.025000    290.870000     11.465000     96.200000
# max     1014.630000     37.950000    312.210000     19.720000    100.000000
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)     sh (g/kg)  \
# count  31931.000000  31931.000000  31931.000000  31931.000000
# mean      15.146275     10.647325      4.498847      6.718122
# std        8.942102      4.077635      6.807391      2.587192
# min        2.170000      2.030000      0.000000      1.260000
# 25%        8.490000      7.520000      0.290000      4.730000
# 50%       13.200000     10.250000      1.820000      6.470000
# 75%       19.435000     13.560000      5.580000      8.550000
# max       66.130000     23.010000     56.720000     14.670000
#
#        H2OC (mmol/mol)  ...      wv (m/s)  max. wv (m/s)      wd (deg)  \
# count     31931.000000  ...  31931.000000   31931.000000  31931.000000
# mean         10.750479  ...      2.057666       3.385259    172.644516
# std           4.123436  ...      1.448510       2.203478     83.729286
# min           2.020000  ...      0.000000       0.000000      0.000000
# 25%           7.590000  ...      0.990000       1.750000    119.500000
# 50%          10.360000  ...      1.710000       2.850000    195.100000
# 75%          13.680000  ...      2.740000       4.490000    224.950000
# max          23.380000  ...     12.810000      17.820000    360.000000
#
#           rain (mm)   raining (s)   SWDR (W/m²)  PAR (µmol/m²/s)  \
# count  31931.000000  31931.000000  31931.000000     31931.000000
# mean       0.009580     31.957032    106.328058       208.339513
# std        0.167079    123.946813    193.646628       376.554554
# min        0.000000      0.000000      0.000000         0.000000
# 25%        0.000000      0.000000      0.000000         0.000000
# 50%        0.000000      0.000000      0.000000         0.000000
# 75%        0.000000      0.000000    121.430000       241.275000
# max       19.200000    600.000000   1044.180000      2026.210000
#
#        max. PAR (µmol/m²/s)   Tlog (degC)     CO2 (ppm)
# count          31931.000000  31931.000000  31931.000000
# mean             250.871895     19.939707    424.905399
# std              479.030428      8.154881    303.832296
# min            -9999.000000      6.410000  -9999.000000
# 25%                0.000000     13.630000    420.100000
# 50%                0.000000     19.150000    430.100000
# 75%              288.995000     25.195000    444.300000
# max             2485.400000     45.800000    530.200000
#
# [8 rows x 21 columns]

# %%
data.drop_duplicates(inplace=True)
data.reset_index(inplace=True,drop=True)
data.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.07.2022 00:10:00    984.33     22.42    296.91        19.72    84.7
# 1  01.07.2022 00:20:00    984.36     22.02    296.50        19.72    86.8
# 2  01.07.2022 00:30:00    984.35     21.77    296.25        19.68    87.9
# 3  01.07.2022 00:40:00    984.27     22.00    296.49        19.47    85.6
# 4  01.07.2022 00:50:00    984.36     22.23    296.71        19.40    84.0
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  wv (m/s)  \
# 0         27.17         23.01          4.16      14.67  ...      1.18
# 1         26.51         23.01          3.50      14.67  ...      1.02
# 2         26.11         22.95          3.16      14.63  ...      0.99
# 3         26.48         22.67          3.81      14.45  ...      1.45
# 4         26.86         22.56          4.30      14.38  ...      1.66
#
#    max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  SWDR (W/m²)  \
# 0           1.63     219.9        0.0            0          0.0
# 1           1.58     222.4        0.0            0          0.0
# 2           1.64     191.0        0.0            0          0.0
# 3           2.40     211.8        0.0            0          0.0
# 4           2.59     211.9        0.0            0          0.0
#
#    PAR (µmol/m²/s)  max. PAR (µmol/m²/s)  Tlog (degC)  CO2 (ppm)
# 0              0.0                   0.0        31.74      447.2
# 1              0.0                   0.0        31.63      445.6
# 2              0.0                   0.0        31.52      443.1
# 3              0.0                   0.0        31.44      443.4
# 4              0.0                   0.0        31.37      444.4
#
# [5 rows x 22 columns]

# %%
data["Date"] = pd.to_datetime(data["Date Time"])

# data["Date"] = data["Date Time"].astype("datetime64[ns]")
data["Date"].shape
# Out:
# (31930,)

# %%
data.set_index("Date Time",inplace=True)
data.drop("Date",axis=1,inplace=True)
data.head()
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# Date Time
# 01.07.2022 00:10:00    984.33     22.42    296.91        19.72    84.7
# 01.07.2022 00:20:00    984.36     22.02    296.50        19.72    86.8
# 01.07.2022 00:30:00    984.35     21.77    296.25        19.68    87.9
# 01.07.2022 00:40:00    984.27     22.00    296.49        19.47    85.6
# 01.07.2022 00:50:00    984.36     22.23    296.71        19.40    84.0
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# Date Time
# 01.07.2022 00:10:00         27.17         23.01          4.16      14.67
# 01.07.2022 00:20:00         26.51         23.01          3.50      14.67
# 01.07.2022 00:30:00         26.11         22.95          3.16      14.63
# 01.07.2022 00:40:00         26.48         22.67          3.81      14.45
# 01.07.2022 00:50:00         26.86         22.56          4.30      14.38
#
#                      H2OC (mmol/mol)  ...  wv (m/s)  max. wv (m/s)  wd (deg)  \
# Date Time                             ...
# 01.07.2022 00:10:00            23.38  ...      1.18           1.63     219.9
# 01.07.2022 00:20:00            23.38  ...      1.02           1.58     222.4
# 01.07.2022 00:30:00            23.32  ...      0.99           1.64     191.0
# 01.07.2022 00:40:00            23.03  ...      1.45           2.40     211.8
# 01.07.2022 00:50:00            22.92  ...      1.66           2.59     211.9
#
#                      rain (mm)  raining (s)  SWDR (W/m²)  PAR (µmol/m²/s)  \
# Date Time
# 01.07.2022 00:10:00        0.0            0          0.0              0.0
# 01.07.2022 00:20:00        0.0            0          0.0              0.0
# 01.07.2022 00:30:00        0.0            0          0.0              0.0
# 01.07.2022 00:40:00        0.0            0          0.0              0.0
# 01.07.2022 00:50:00        0.0            0          0.0              0.0
#
#                      max. PAR (µmol/m²/s)  Tlog (degC)  CO2 (ppm)
# Date Time
# 01.07.2022 00:10:00                   0.0        31.74      447.2
# 01.07.2022 00:20:00                   0.0        31.63      445.6
# 01.07.2022 00:30:00                   0.0        31.52      443.1
# 01.07.2022 00:40:00                   0.0        31.44      443.4
# 01.07.2022 00:50:00                   0.0        31.37      444.4
#
# [5 rows x 21 columns]

# %%
# feature selection
data_selected = data.iloc[:, [0,1,4,8,16,20]]
display(data_selected.head())
# Out:
#                      p (mbar)  T (degC)  rh (%)  sh (g/kg)  SWDR (W/m²)  \
# Date Time
# 01.07.2022 00:10:00    984.33     22.42    84.7      14.67          0.0
# 01.07.2022 00:20:00    984.36     22.02    86.8      14.67          0.0
# 01.07.2022 00:30:00    984.35     21.77    87.9      14.63          0.0
# 01.07.2022 00:40:00    984.27     22.00    85.6      14.45          0.0
# 01.07.2022 00:50:00    984.36     22.23    84.0      14.38          0.0
#
#                      CO2 (ppm)
# Date Time
# 01.07.2022 00:10:00      447.2
# 01.07.2022 00:20:00      445.6
# 01.07.2022 00:30:00      443.1
# 01.07.2022 00:40:00      443.4
# 01.07.2022 00:50:00      444.4

# %%
col_names = list(data_selected.columns)
colors = ['b','g','r','c','m','y']

# %%
n_features=6
n_steps_in=50
n_steps_out=20

# %% [markdown]
# ### Scaling & Anomaly detection

# %%
# scale data
# scaler = MinMaxScaler(feature_range=(-1,1))
# data_scaled = scaler.fit_transform(data_selected)

# %%
# train and test split
data_array=np.array(data_selected)
test_size = 1010
train = data_array[:-test_size,:]
test = data_array[-test_size:,:]

# %%
print(train.shape)
print(test.shape)
# Out:
# (30920, 6)
# (1010, 6)

# %%
def plot_histogram(y,x,train,column_names,colors):
    plt.figure(figsize=(20,20))
    for i in range(train.shape[1]):
        plt.subplot(y,x,i+1)
        plt.hist(train[:,i],color=colors[i])
        plt.title(col_names[i])

    plt.show()

# %%
def plot_boxplot(y,x,train,column_names,colors):
    plt.figure(figsize=(20,20))
    for i in range(train.shape[1]):
        plt.subplot(y,x,i+1)
        plt.boxplot(train[:,i])
        plt.title(col_names[i])

    plt.show()

# %%
plot_histogram(3,2,train,col_names,colors)

# %%
plot_boxplot(3,2,train,col_names,colors)

# %%
def remove_anomaly(train,index,anomaly_idx_list):
    offset=100
    for i in range(len(anomaly_idx_list)):
        size = 0
        mean = 0
        for j in range(anomaly_idx_list[i]-offset,anomaly_idx_list[i]+offset+1):
            if(train.shape[0]-(offset+1)>=j>=0 and j not in anomaly_idx_list ):
                size += 1
                mean += train[j,index]
#         print(mean/size)
        if size != 0:
            train[anomaly_idx_list[i],index] = mean/size
    return train

# %%
isolation_forest = IsolationForest(contamination=0.01)

for idx in range(train.shape[1]):
    dt_feature = [[item] for item in train[:,idx]]
    isolation_forest.fit(dt_feature)
    pred = isolation_forest.predict(dt_feature)
    anomaly = [i for i in range(len(pred)) if pred[i] == -1]
    
    train = remove_anomaly(train,idx,anomaly)
    
    anomaly_val = []
    for i in range(len(anomaly)):
        anomaly_val.append(dt_feature[anomaly[i]])
    plt.plot(dt_feature,color='b')
    plt.title(col_names[idx])
    plt.scatter(anomaly,anomaly_val,color='r')
    plt.legend(['original','anomaly'], loc='upper right')
    plt.show()

# %%
plot_boxplot(3,2,train,col_names,colors)

# %%
for i in range(train.shape[1]):
    plt.plot(train[:3000,i],color=colors[i])
    plt.title(col_names[i])
    plt.show()

# %%
# for i in range(test.shape[1]):
#     plt.plot(test[:,i],color=colors[i])
#     plt.title(col_names[i])
#     plt.show()

# %% [markdown]
# ### Identifying Stationarity

# %%
# check stationarity std and mean
for i in range(n_features):
    print("{:<20} mean: {:<20} variance: {:<20}".format(col_names[i],np.mean(train[:,i]),np.var(train[:,i])))
# Out:
# p (mbar)             mean: 990.2691041681932    variance: 58.86428658589816
# T (degC)             mean: 11.231170949571354   variance: 71.91905849803048
# rh (%)               mean: 79.50648747446014    variance: 359.59999610388564
# sh (g/kg)            mean: 6.8080954556767725   variance: 6.437967824922586
# SWDR (W/m²)          mean: 101.4911114750129    variance: 32554.50187058142
# CO2 (ppm)            mean: 433.1954017302544    variance: 321.9971455225938

# %%
# split data set into chunk and calculate mean and std
for i in range(n_features):
    chunk = np.split(train[:,i], indices_or_sections=10)
    print("{:^75}\n\nmean: {}\n\nvariance: {}".format(col_names[i],np.mean(chunk,axis=1),np.var(chunk,axis=1)))
    print("---------------------------------------------------------------------")
# Out:
#                                  p (mbar)
#
# mean: [994.63727684 992.38136158 989.59104787 988.59766171 989.57018111
#  992.28054657 988.15962807 989.62546248 987.9425194  989.90535604]
#
# variance: [ 10.7522237   17.81019676  19.56834237  31.78650608  81.4973402
#   28.5934606  104.64508178  52.9410568   44.61509129 154.69365479]
# ---------------------------------------------------------------------
#                                  T (degC)
#
# mean: [19.28086155 20.76830088 19.73922057 14.03266818 11.52739974 12.45497736
#   5.38193079 -1.13170909  8.50964748  1.74841203]
#
# variance: [26.38827373 23.35148545 19.49485272 23.41010009 16.56734563 20.00816161
#  26.70390717 15.28972095 10.51939577 15.49840708]
# ---------------------------------------------------------------------
#                                   rh (%)
#
# mean: [61.29913047 56.30271711 71.20894567 82.65258732 83.62888745 85.14352846
#  89.18570181 94.53805627 82.55940168 88.5459185 ]
#
# variance: [376.96180433 355.11061012 393.8170756  265.40590663 187.98352955
#  181.83786358 148.27701597  53.11234114 118.15205433 107.23454531]
# ---------------------------------------------------------------------
#                                  sh (g/kg)
#
# mean: [ 7.97509511  8.36350562 10.02766108  8.3965706   7.18005175  7.81305627
#   5.1348674   3.45604259  5.80924968  3.92485446]
#
# variance: [2.4438748  3.33034136 3.88034244 4.18726329 1.93948958 2.96117698
#  1.62255965 1.03522573 0.93211114 0.88222847]
# ---------------------------------------------------------------------
#                                 SWDR (W/m²)
#
# mean: [196.74560477 218.43197549 174.62047815 130.92176915 107.0650194
#   65.89162031  45.04640039  23.52623868  25.39621928  27.26578913]
#
# variance: [55322.30359062 67938.12929234 54900.81176603 38723.76368883
#  27886.63671821 12571.77977781  7501.43728714  3348.38942431
#   2581.02371103  3945.34128253]
# ---------------------------------------------------------------------
#                                  CO2 (ppm)
#
# mean: [423.68567966 421.63252758 429.78138351 430.86680332 429.71035099
#  441.28422991 441.6549597  449.74830255 430.15452781 433.43525226]
#
# variance: [253.91388418 206.08650694 414.78799179 478.09734191 315.23734497
#  332.92088654 195.41826363 223.95286984  50.15128286  75.75051019]
# ---------------------------------------------------------------------

# %%
# Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller
for i in range(n_features):
    adf, pvalue, usedlag, nobs, critical_values, icbest = adfuller(train[:,i])
    print("{:<20s} adf: {:<20} pvalue: {:<20}".format(col_names[i],adf,pvalue))
# Out:
# p (mbar)             adf: -6.699946334268462   pvalue: 3.9122798910717975e-09
# T (degC)             adf: -6.097516956671746   pvalue: 1.0017583532783176e-07
# rh (%)               adf: -12.433145643567789  pvalue: 3.899777810078541e-23
# sh (g/kg)            adf: -4.712013580765644   pvalue: 7.988689343718299e-05
# SWDR (W/m²)          adf: -24.717793421931557  pvalue: 0.0
# CO2 (ppm)            adf: -19.032280727389644  pvalue: 0.0

# %% [markdown]
# 1. If **p value** is high, data is nonstationary. It should be less than 0.05
# 2. **Adf** is the value of the test statistic. The more negative the value, the more confident we can be that the series is stationary.

# %%
# plot autocorrelation  and partial autocorrelation  graphs
# autocorrelation is for optimal d, partial autocorrelation is for optimal p
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

def plot_acf_pacf(train):
    for i in range(train.shape[1]):
        fig, axes = plt.subplots(1, 2, sharex=True)
        plot_acf(train[:,i], ax=axes[0])
        plot_pacf(train[:,i], ax=axes[1])
    plt.show()
plot_acf_pacf(train)

# %%
# difference
def optimal_d(train):
    for i in range(train.shape[1]):
        fig, axes = plt.subplots(1, 2, sharex=True)
        plot_pacf(np.diff(train[:,i]), ax=axes[0])
        plot_acf(np.diff(train[:,i]), ax=axes[1])
#         plot_pacf(np.diff(np.diff(train[:,i])), ax=axes[2])
#         plot_acf(np.diff(np.diff(train[:,i])), ax=axes[3])
        
    plt.show()
optimal_d(train)

# %% [markdown]
# ### Arima Model Implementation & Prediction

# %%
def plot_arima(idx,train,test,forecast,test_size,train_range,conf_int,title):
    plt.plot(range(train_range),train[-train_range:,idx],color='blue')
    plt.plot(range(train_range,train_range+test_size),test[:,idx],color='orange')
    plt.plot(range(train_range,train_range+test_size),forecast,color='green')
#     plt.fill_between(range(train_range,train_range+test_size),
#                     conf_int[:, 0], conf_int[:, 1],
#                     alpha=0.1, color='b')
    plt.legend(["train","test","predicted"])
    plt.title(title)
    plt.show()

# %%
from pmdarima import auto_arima
# pressure
model_p = auto_arima(y=train[:,0],X=train[:,1:],seasonal=False,out_of_sample_size=20,max_p=10,max_q=10)
print(model_p.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(4, 1, 6)   Log Likelihood               22957.215
# Date:                Tue, 28 Mar 2023   AIC                         -45882.431
# Time:                        18:18:08   BIC                         -45749.005
# Sample:                             0   HQIC                        -45839.681
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0107      0.002     -4.642      0.000      -0.015      -0.006
# x2             0.0027      0.001      3.897      0.000       0.001       0.004
# x3            -0.0056      0.007     -0.829      0.407      -0.019       0.008
# x4         -4.919e-05   8.67e-06     -5.675      0.000   -6.62e-05   -3.22e-05
# x5            -0.0001      0.000     -0.581      0.561      -0.001       0.000
# ar.L1         -0.0446      0.209     -0.213      0.831      -0.454       0.365
# ar.L2          0.3662      0.124      2.964      0.003       0.124       0.608
# ar.L3          0.1848      0.168      1.100      0.271      -0.144       0.514
# ar.L4          0.4326      0.156      2.779      0.005       0.128       0.738
# ma.L1          0.1068      0.209      0.512      0.609      -0.302       0.516
# ma.L2         -0.2924      0.129     -2.270      0.023      -0.545      -0.040
# ma.L3         -0.1240      0.152     -0.815      0.415      -0.422       0.174
# ma.L4         -0.3814      0.142     -2.677      0.007      -0.661      -0.102
# ma.L5          0.0294      0.006      5.288      0.000       0.018       0.040
# ma.L6         -0.0027      0.006     -0.461      0.645      -0.014       0.009
# sigma2         0.0133   5.11e-06   2596.595      0.000       0.013       0.013
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):        4740781926.50
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.81   Skew:                            10.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                      1921.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast_p,conf_int=model_p.predict(n_periods=test_size,X=test[:,1:],return_conf_int=True)
print("Mean squared error: ",mean_squared_error(forecast_p,test[:,0]))
print(forecast_p)
train_range=1000
plot_arima(0,train,test,forecast_p,test_size,train_range,conf_int,col_names[0])
# Out:
# Mean squared error:  465.21591435310506
# [988.13303673 988.05832585 987.9858612  ... 984.57086596 984.57150599
#  984.57282162]

# %%
# temparature
model_temp = auto_arima(y=train[:,1],X=train[:,np.r_[0,2:]],seasonal=True,out_of_sample_size=20,max_p=10,max_q=10)
print(model_temp.summary())
forecast_temp, conf_int_t = model_temp.predict(n_periods=test_size,X=test[:,np.r_[0,2:]],return_conf_int=True)
print("Mean squared error: ",mean_squared_error(forecast_temp,test[:,1]))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(1, 1, 0)   Log Likelihood              356466.767
# Date:                Tue, 28 Mar 2023   AIC                        -712921.534
# Time:                        18:37:16   BIC                        -712871.499
# Sample:                             0   HQIC                       -712905.503
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1.573e-06   3.06e-08    -51.308      0.000   -1.63e-06   -1.51e-06
# x1            -0.0444   3.13e-08  -1.42e+06      0.000      -0.044      -0.044
# x2             0.0444   3.13e-08   1.42e+06      0.000       0.044       0.044
# x3             1.0000   4.45e-09   2.25e+08      0.000       1.000       1.000
# ar.L1          0.2071   7.07e-14   2.93e+12      0.000       0.207       0.207
# sigma2      8.572e-12   1.52e-11      0.563      0.573   -2.13e-11    3.84e-11
# ===================================================================================
# Ljung-Box (L1) (Q):                 134.48   Jarque-Bera (JB):         247769241.76
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.43   Skew:                             0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                       441.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.32e+27. Standard errors may be unstable.
# Mean squared error:  1.4335113113993584e-06

# %%
plot_arima(1,train,test,forecast_temp,test_size,train_range,conf_int_t,col_names[1])

# %%
plt.plot(range(train_range),train[-train_range:,1],color='blue')
plt.plot(range(train_range,train_range+test_size),test[:,1],color='orange')
plt.legend(["train","test"])
plt.title("Temp Train-Test")
plt.show()

# %%
# rh
from statsmodels.tsa.seasonal import seasonal_decompose
fig=seasonal_decompose(train[:,2],period=150).plot()
fig.set_size_inches((15, 12))
fig.tight_layout()

# %%
model_rh = auto_arima(train[:,2],X=train[:,np.r_[0:2,3:]],seasonality=True,stationary=False,out_of_sample_size=20)
print(model_rh.summary())
forecast_rh, conf_int= model_rh.predict(n_periods=test_size,X=test[:,np.r_[0:2,3:]],return_conf_int =True)
print("Mean squared error: ",mean_squared_error(forecast_rh,test[:,2]))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(1, 1, 0)   Log Likelihood              321607.518
# Date:                Tue, 28 Mar 2023   AIC                        -643199.037
# Time:                        19:02:28   BIC                        -643132.324
# Sample:                             0   HQIC                       -643177.662
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -5.86e-06    9.3e-08    -63.028      0.000   -6.04e-06   -5.68e-06
# x1          5.459e-05   1.82e-08   3004.365      0.000    5.46e-05    5.46e-05
# x2             0.0367   1.52e-08   2.42e+06      0.000       0.037       0.037
# x3         -3.587e-05   1.82e-08  -1974.039      0.000   -3.59e-05   -3.58e-05
# x4            -0.0367   1.52e-08  -2.42e+06      0.000      -0.037      -0.037
# x5             1.0000   9.94e-09   1.01e+08      0.000       1.000       1.000
# ar.L1          0.1684   2.34e-13   7.19e+11      0.000       0.168       0.168
# sigma2      6.925e-11   1.92e-11      3.615      0.000    3.17e-11    1.07e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                 167.58   Jarque-Bera (JB):          43910280.02
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -2.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                       187.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.04e+26. Standard errors may be unstable.
# Mean squared error:  1.4534542099985142e-05

# %%
plot_arima(2,train,test,forecast_rh,test_size,train_range,conf_int,col_names[2])

# %%
plt.plot(range(train_range),train[-train_range:,2],color='blue')
plt.plot(range(train_range,train_range+test_size),test[:,2],color='orange')
plt.legend(["train","test"])
plt.title("rh Train-Test")
plt.show()

# %%
# sh
model_sh = auto_arima(train[:,3],X=train[:,np.r_[0:3,4:]],seasonality=True,stationary=False,out_of_sample_size=20)
print(model_sh.summary())
forecast_sh, conf_int= model_sh.predict(n_periods=test_size,X=test[:,np.r_[0:3,4:]],return_conf_int =True)
print("Mean squared error: ",mean_squared_error(forecast_temp,test[:,3]))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(0, 1, 4)   Log Likelihood              323437.601
# Date:                Tue, 28 Mar 2023   AIC                        -646851.202
# Time:                        20:47:31   BIC                        -646751.133
# Sample:                             0   HQIC                       -646819.140
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.913e-07   3.44e-07      0.848      0.397   -3.82e-07    9.65e-07
# x2            -0.0015   4.97e-09  -2.98e+05      0.000      -0.001      -0.001
# x3         -2.731e-06   2.44e-09  -1120.344      0.000   -2.74e-06   -2.73e-06
# x4         -3.613e-07   3.44e-07     -1.051      0.293   -1.03e-06    3.12e-07
# x5             0.0015   4.97e-09   2.93e+05      0.000       0.001       0.001
# x6         -1.529e-06   2.44e-09   -627.030      0.000   -1.53e-06   -1.52e-06
# x7             1.0000   1.86e-07   5.39e+06      0.000       1.000       1.000
# ma.L1          0.1030   4.11e-11    2.5e+09      0.000       0.103       0.103
# ma.L2          0.1339   1.12e-11    1.2e+10      0.000       0.134       0.134
# ma.L3          0.0066    2.4e-12   2.76e+09      0.000       0.007       0.007
# ma.L4          0.1162    4.7e-12   2.47e+10      0.000       0.116       0.116
# sigma2      6.686e-11   1.12e-11      5.943      0.000    4.48e-11    8.89e-11
# ===================================================================================
# Ljung-Box (L1) (Q):                1096.50   Jarque-Bera (JB):         323768984.57
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.16   Skew:                            -1.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                       504.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.36e+26. Standard errors may be unstable.
# Mean squared error:  15.813001143544247

# %%
plot_arima(3,train,test,forecast_sh,test_size,train_range,conf_int,col_names[3])

# %%
plt.plot(range(train_range),train[-train_range:,3],color='blue')
plt.plot(range(train_range,train_range+test_size),test[:,3],color='orange')
plt.legend(["train","test"])
plt.title("sh Train-Test")
plt.show()

# %%
#swdr
model_swdr = auto_arima(train[:,4],X=train[:,np.r_[0:4,5]],seasonality=True,stationary=False,out_of_sample_size=20)
print(model_swdr.summary())
forecast_swdr, conf_int= model_swdr.predict(n_periods=test_size,X=test[:,np.r_[0:4,5]],return_conf_int =True)
print("Mean squared error: ",mean_squared_error(forecast_temp,test[:,4]))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(1, 1, 1)   Log Likelihood             -171658.249
# Date:                Tue, 28 Mar 2023   AIC                         343332.498
# Time:                        21:08:18   BIC                         343399.211
# Sample:                             0   HQIC                        343353.873
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             6.2441      2.082      2.999      0.003       2.164      10.324
# x2            16.4509      0.498     33.065      0.000      15.476      17.426
# x3            -1.2243      0.138     -8.860      0.000      -1.495      -0.953
# x4            28.2584      1.703     16.590      0.000      24.920      31.597
# x5             0.0155      0.175      0.088      0.930      -0.328       0.359
# ar.L1          0.1815      0.004     46.097      0.000       0.174       0.189
# ma.L1         -0.5806      0.004   -146.046      0.000      -0.588      -0.573
# sigma2      3872.2343      8.689    445.654      0.000    3855.204    3889.264
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1354784.25
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.03   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        35.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean squared error:  8558.514082915523

# %%
plot_arima(4,train,test,forecast_swdr,test_size,train_range,conf_int,col_names[4])

# %%
# co2
model_co2 = auto_arima(train[:,5],X=train[:,:5],seasonality=True,stationary=False,out_of_sample_size=20)
print(model_co2.summary())
forecast_co2, conf_int= model_co2.predict(n_periods=test_size,X=test[:,:5],return_conf_int =True)
print("Mean squared error: ",mean_squared_error(forecast_temp,test[:,5]))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                30920
# Model:               SARIMAX(4, 1, 3)   Log Likelihood              -80205.711
# Date:                Tue, 28 Mar 2023   AIC                         160437.423
# Time:                        22:14:28   BIC                         160545.831
# Sample:                             0   HQIC                        160472.157
#                               - 30920
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0226      0.133      0.170      0.865      -0.237       0.283
# x2            -0.8978      0.027    -33.852      0.000      -0.950      -0.846
# x3             0.4664      0.007     71.413      0.000       0.454       0.479
# x4            -0.5136      0.111     -4.610      0.000      -0.732      -0.295
# x5            -0.0002      0.000     -0.312      0.755      -0.001       0.001
# ar.L1         -0.0181      0.023     -0.790      0.429      -0.063       0.027
# ar.L2          0.7987      0.006    133.973      0.000       0.787       0.810
# ar.L3          0.0261      0.016      1.628      0.103      -0.005       0.058
# ar.L4          0.0889      0.002     35.830      0.000       0.084       0.094
# ma.L1         -0.0945      0.023     -4.120      0.000      -0.140      -0.050
# ma.L2         -0.9343      0.006   -144.146      0.000      -0.947      -0.922
# ma.L3          0.0660      0.018      3.675      0.000       0.031       0.101
# sigma2        10.4697      0.021    495.937      0.000      10.428      10.511
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.60   Jarque-Bera (JB):          10389842.35
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.28   Skew:                             0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        92.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean squared error:  188394.54057532674

# %%
plot_arima(5,train,test,forecast_co2,test_size,train_range,conf_int,col_names[5])

# %%
# save the models
# import pickle
# with open('arimamodels\model_co2.pkl','wb') as file:
#     pickle.dump(model_co2,file)
# with open('arimamodels\model_swdr.pkl','wb') as file:
#     pickle.dump(model_swdr,file)
# with open('arimamodels\model_sh.pkl','wb') as file:
#     pickle.dump(model_sh,file)
# with open('arimamodels\model_rh.pkl','wb') as file:
#     pickle.dump(model_rh,file)
# with open('arimamodels\model_temp.pkl','wb') as file:
#     pickle.dump(model_temp,file)
# with open('arimamodels\model_p.pkl','wb') as file:
#     pickle.dump(model_p,file)

# %%
# Open the file in binary mode
# with open('arimamodels\model_co2.pkl', 'rb') as file:
#     # Call load method to deserialze
#     model_co2 = pickle.load(file)
# with open('arimamodels\model_swdr.pkl', 'rb') as file:
#     model_swdr = pickle.load(file)
# with open('arimamodels\model_sh.pkl', 'rb') as file:
#     model_sh = pickle.load(file)
# with open('arimamodels\model_rh.pkl', 'rb') as file:
#     model_rh = pickle.load(file)
# with open('arimamodels\model_temp.pkl', 'rb') as file:
#     model_temp = pickle.load(file)
# with open('arimamodels\model_p.pkl', 'rb') as file:
#     model_p = pickle.load(file)
